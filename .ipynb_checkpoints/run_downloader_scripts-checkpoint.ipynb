# 2021-09-29 2021-10-05
# Data downloaded from cloud and appended to existing file
# REQUESTING DATA FOR AQY BB-804
# 2021-09-29 2021-10-05
# Data downloaded from cloud and appended to existing file
# REQUESTING DATA FOR AQY BB-806
# 2021-09-29 2021-10-05
# Data downloaded from cloud and appended to existing file
# REQUESTING DATA FOR AQY BB-808
# 2021-09-29 2021-10-05
# Data downloaded from cloud and appended to existing file
# REQUESTING DATA FOR AQY BB-809
# 2021-08-14 2021-08-20
# 2021-08-21 2021-08-27
# 2021-08-28 2021-09-03
# 2021-09-04 2021-09-10
# 2021-09-11 2021-09-17
# 2021-09-18 2021-09-24
# 2021-09-25 2021-10-01
# 2021-10-02 2021-10-06
# Data downloaded from cloud and appended to existing file
# REQUESTING DATA FOR AQY BB-807
# 2021-09-29 2021-10-05
# Data downloaded from cloud and appended to existing file
# REQUESTING DATA FOR AQY BB-810
# 2021-09-29 2021-10-05
# Data downloaded from cloud and appended to existing file
# REQUESTING DATA FOR AQY BB-811
# 2021-09-29 2021-10-05
# Data downloaded from cloud and appended to existing file
# REQUESTING DATA FOR AQY BB-897
# 2021-09-29 2021-10-05
# Data downloaded from cloud and appended to existing file
# REQUESTING DATA FOR AQY BB-898
# 2021-09-29 2021-10-05
# Data downloaded from cloud and appended to existing file
# REQUESTING DATA FOR AQY BE-645A
# 2021-09-29 2021-10-05
# Data downloaded from cloud and appended to existing file
# REQUESTING DATA FOR AQY BE-803A
# 2021-09-29 2021-10-05
# Data downloaded from cloud and appended to existing file
# REQUESTING DATA FOR AQY BB-633A
# 2021-09-16 2021-09-22
# 2021-09-23 2021-09-29
# 2021-09-30 2021-10-06
# Data downloaded from cloud and appended to existing file

# %%
rich_min_concat_raw = avg.read_and_concat_min_data(sacramento=False)
rich_min_concat = avg.clean_concatenated_data(rich_min_concat_raw)

rich_min_avg_10 = avg.average_minute_data(rich_min_concat, 'ten')
rich_min_avg_60 = avg.average_minute_data(rich_min_concat, 'sixty')
# Out:
# Concatenated all minute data files
# C:\Users\18313\Desktop\richmond_air\ramn_data_processing\averaging_scripts.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   minute_network['time'] = minute_network['Time'].str[0:timestamp_cutoff]
# C:\Users\18313\Desktop\richmond_air\ramn_data_processing\averaging_scripts.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   minute_network['minutes_observed'] = minute_network.groupby(['ID', 'time'])['time'].transform('count')

# %%
from datetime import date

file_suffix = date.today().strftime("%Y-%m-%d") + '.csv'

min_file_10 = 'results_downloader_data/time_averaged/PSE_AQY_10_min_' + file_suffix
min_file_60 = 'results_downloader_data/time_averaged/PSE_AQY_60_min_' + file_suffix

rich_min_avg_10.to_csv(min_file_10, index = False)
rich_min_avg_60.to_csv(min_file_60, index = False)

# %% [markdown]
# ### Sacramento Data Download

# %%
aqcloud_login = dl.create_aqc_login('lhill@psehealthyenergy.org', 'R1chmond@ir')

no_sacramento = ['AQY BB-896', 'AQY BB-897', 'AQY BB-898', 'AQY BE-645A', 'AQY BE-803A', 'AQY BB-633A']

aqys_available_list = dl.get_instruments_available(aqcloud_login)
aqys_available_list = [aqy for aqy in aqys_available_list if aqy not in no_sacramento]

for aqy in aqys_available_list:
    
    print('REQUESTING DATA FOR', aqy)
    
    dl.get_aqy_data_for_full_deployment(aqcloud_login, aqy, sacramento=True)

# %%
sac_min_concat_raw = avg.read_and_concat_min_data(sacramento=True)

sac_min_concat = avg.clean_concatenated_data(sac_min_concat_raw)

sac_min_avg_10 = avg.average_minute_data(sac_min_concat, 'ten')
sac_min_avg_60 = avg.average_minute_data(sac_min_concat, 'sixty')

# %%
sac_min_avg_10.to_csv('results_downloader_data/time_averaged/sac_colocation_ten_min.csv', index = False)
sac_min_avg_60.to_csv('results_downloader_data/time_averaged/sac_colocation_sixty_min.csv', index = False)
